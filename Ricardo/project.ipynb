# %% [markdown]
# # Real Estate Clean up
#
# This is a real dataset and it was downloaded using web scraping techniques. The data contains registers from fotocasa which is one of the most popular websites of real estate in Spain. Please, do not do this (web scraping) unless it is for academic purposes.
#
# The dataset was downloaded a few years ago by Henry Navarro and In no case were economic returns obtained from it.
#
# It contains thousands of data from real houses published on the web www.fotocasa.com. Your goal is to extract as much information as possible with the knowledge you have so far about data science, for example what is the most expensive house in the entire dataset?
#
# Let's start with precisely that question... Good luck!

# %% [markdown]
# #### Exercise 00. Read the dataset assets/real_estate.csv and try to visualize the table (★☆☆)

# %%
import pandas as pd

# this CSV file contains semicolons instead of comas as separator
ds = pd.read_csv('../assets/real_estate.csv', sep=';')
ds
# Out:
#        Unnamed: 0  id_realEstates  isNew                    realEstate_name  \
# 0               1       153771986  False            ferrari 57 inmobiliaria
# 1               2       153867863  False  tecnocasa fuenlabrada ferrocarril
# 2               3       153430440  False                 look find boadilla
# 3               4       152776331  False  tecnocasa fuenlabrada ferrocarril
# 4               5       153180188  False            ferrari 57 inmobiliaria
# ...           ...             ...    ...                                ...
# 15330       15331       153901377  False                infocasa consulting
# 15331       15332       150394373  False                inmobiliaria pulpon
# 15332       15333       153901397  False             tecnocasa torrelodones
# 15333       15334       152607440  False                inmobiliaria pulpon
# 15334       15335       153901356  False                infocasa consulting
#
# ...

# %% [markdown]
# #### Exercise 01. Which is the most expensive house in the dataset? (★☆☆)
#
# Print the address and the price of the selected house. For example:
#
# `The house with address General Street Nº5 is the most expensive and its price is 5000000 USD`

# %%
most_expensive = ds['price'].idxmax()
most_expensive_price = ds.at[most_expensive, 'price']
most_expensive_address = ds.at[most_expensive, 'address']

print(f"The most expensive house has a price of {most_expensive_price} USD and its address is {most_expensive_address}.")
# Out:
# The most expensive house has a price of 8500000 USD and its address is El Escorial.

# %% [markdown]
# #### Exercise 02. Which is cheapest house in the dataset? (★☆☆)
#
# Print the address and the price of the selected house. For example:
#
# `The house with address Concrete Street Nº1 is the cheapest and its price is 12000 USD`

# %%
filtered_ds = ds[ds['price'] > 0]

least_expensive = filtered_ds['price'].idxmin()

least_expensive_price = filtered_ds.at[least_expensive, 'price']
least_expensive_address = filtered_ds.at[least_expensive, 'address']

print(f"The least expensive house has a price of {least_expensive_price} USD and its address is {least_expensive_address}.")
# Out:
# The least expensive house has a price of 600 USD and its address is Berlin, Coslada.

# %% [markdown]
# #### Exercise 03. Which is the biggest and the smallest house in the dataset? (★☆☆)
#
# Print both the address and the surface of the selected houses. For example:
#
# `The bigger house is located on Yukka Street Nº10 and its surface is 5000 meters`
#
# `The smaller house is located on County Road 1 N and its surface is 200 meters`

# %%
biggest_house = ds['surface'].idxmax()
smallest_house = ds['surface'].idxmin()

biggest_house_address = ds.at[biggest_house, 'address']
smallest_house_address = ds.at[smallest_house, 'address']

print(f"The biggest house is located on {biggest_house_address} and has a surface of {biggest_house} meters")
print(f"The smallest house is located on {smallest_house_address} and has a surface of {smallest_house} meters")
# Out:
# The biggest house is located on Sevilla la Nueva and has a surface of 6794 meters
# The smallest house is located on Calle Amparo,  Madrid Capital and has a surface of 498 meters

# %% [markdown]
# #### Exercise 04. How many populations (level5 column) the dataset contains? (★☆☆)
#
# Print the name of the populations with comma as separator. For example:
#
# `> print(populations)`
#
# `population1, population2, population3,...`

# %%
populations = ds['level5'].unique()

populations_str = ','.join(populations)

print(populations_str)
# Out:
# Arganda del Rey,Fuenlabrada,Boadilla del Monte,Las Rozas de Madrid, Madrid Capital,Villaviciosa de Odón,Pinto,Valdemoro,Navalcarnero,Pozuelo de Alarcón,Torrejón de Ardoz,Navalagamella,San Sebastián de los Reyes,Rivas-vaciamadrid,Alpedrete,Móstoles,San Fernando de Henares,Coslada,Becerril de la Sierra,Alcalá de Henares,Chinchón,Parla,Alcorcón,El Escorial,Leganés,Pedrezuela,Majadahonda,Villanueva de la Cañada,Villanueva del Pardillo,Torrelodones,Moralzarzal,Mejorada del Campo,Aranjuez,Corpa,Getafe,Velilla de San Antonio,Sevilla la Nueva,San Martín de la Vega,Villalbilla,Collado Villalba,Alcobendas,El Molar (Madrid),Moraleja de Enmedio,Algete,Campo Real,Torrejón de la Calzada,Colmenar Viejo,Valdemorillo,Fuente El Saz de Jarama,Tres Cantos,Arroyomolinos (Madrid),Griñón,Paracuellos de Jarama,Guadarrama,Titulcia,Galapagar,Collado Mediano,Los Molinos,San Lorenzo de El Escorial,Loeches,San Martín de Valdeiglesias,Navas del Rey,Bustarviejo,Manzanares El Real,Carabaña,Casarrubuelos,Cercedilla,
# ...

# %% [markdown]
# #### Exercise 05. Does the dataset contain NAs? (★☆☆)
#
# Print a boolean value (`true` or `fase`) followed by the rows/cols that contains NAs.

# %%
has_nas = ds.isna().any().any()

print(has_nas)

if has_nas:
 
    rows_with_nas = ds[ds.isna().any(axis=1)]
    print("\nRows with NAs:")
    print(rows_with_nas)

   
    cols_with_nas = ds.columns[ds.isna().any()].tolist()
    print("\nColumns with NAs:", cols_with_nas)
# Out:
# True
#
# Rows with NAs:
#        Unnamed: 0  id_realEstates  isNew                    realEstate_name  \
# 0               1       153771986  False            ferrari 57 inmobiliaria
# 1               2       153867863  False  tecnocasa fuenlabrada ferrocarril
# 2               3       153430440  False                 look find boadilla
# 3               4       152776331  False  tecnocasa fuenlabrada ferrocarril
# 4               5       153180188  False            ferrari 57 inmobiliaria
# ...           ...             ...    ...                                ...
# 15330       15331       153901377  False                infocasa consulting
# 15331       15332       150394373  False                inmobiliaria pulpon
# 15332       15333       153901397  False             tecnocasa torrelodones
# 15333       15334       152607440  False                inmobiliaria pulpon
# 15334       15335       153901356  False                infocasa consulting
#
# ...

# %% [markdown]
# #### Exercise 06. Delete the NAs of the dataset, if applicable (★★☆)
#
# Print a comparison between the dimensions of the original DataFrame versus the DataFrame after the deletions

# %%
original_dims = ds.shape

ds_cleaned = ds.dropna()

clean_dims = ds_cleaned.shape

print("The original dimensions are:", original_dims)
print("The dimensions after deleting NAs:", clean_dims)
# Out:
# The original dimensions are: (15335, 37)
# The dimensions after deleting NAs: (0, 37)

# %% [markdown]
# #### Exercise 07. Which is the mean of prices in the population (level5 column) of "Arroyomolinos (Madrid)"? (★★☆)
#
# Print the obtained value

# %%
population_name = "Arroyomolinos (Madrid)"
mean_price = ds.loc[ds['level5'] == population_name, 'price'].mean()

print("Mean price in", population_name, ":", mean_price, "USD.")
# Out:
# Mean price in Arroyomolinos (Madrid) : 294541.59854014596 USD.

# %% [markdown]
# #### Exercise 08. Plot the histogram of prices for the population (level5 column) of "Arroyomolinos (Madrid)" and explain what you observe (★★☆)
#
# Print the histogram of the prices and write in the Markdown cell a brief analysis about the plot.

# %%
import matplotlib.pyplot as plt

arroyomolinos_prices = ds.loc[ds['level5'] == "Arroyomolinos (Madrid)", 'price']

plt.figure(figsize=(10, 6))
plt.hist(arroyomolinos_prices, bins=20, edgecolor='black', alpha=0.7)
plt.title("Histogram of Prices in Arroyomolinos (Madrid)")
plt.xlabel("Price")
plt.ylabel("Frequency")
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %% [markdown]
# First thing you see is the outlier in the far left of the histogram. Looking at the rest of the histogram (not taking into considration the outlier price of 0), it has characteristics of a normal distribution curve. However, with the lower frequency on the higher prices, you could make the argument that it is rght-skewed.

# %% [markdown]
# #### Exercise 09. Is the average of "Valdemorillo" and "Galapagar" prices the same? (★★☆)
#
# Print the both average prices and then write a conclusion about them

# %%
import pandas as pd


valdemorillo_prices = ds.loc[ds['level5'] == "Valdemorillo", 'price']
galapagar_prices = ds.loc[ds['level5'] == "Galapagar", 'price']

average_valdemorillo_price = valdemorillo_prices.mean()
average_galapagar_price = galapagar_prices.mean()

print("Average price in Valdemorillo:", average_valdemorillo_price, "USD.")
print("Average price in Galapagar:", average_galapagar_price, "UDS.")

if average_valdemorillo_price == average_galapagar_price:
    print("The average prices in Valdemorillo and Galapagar are the same.")
else:
    print("The average prices in Valdemorillo and Galapagar are different.")
# Out:
# Average price in Valdemorillo: 363860.2931034483 USD.
# Average price in Galapagar: 360063.20238095237 UDS.
# The average prices in Valdemorillo and Galapagar are different.

# %% [markdown]
# The average prices are different. The averge price of Valdemorillo is more expensive than the avergae price of Galapagar by a total of 3797.0907225 USD.

# %% [markdown]
# #### Exercise 10. Is the average of "Valdemorillo" and "Galapagar" price per square meter (price/m2) the same? (★★☆)
#
# Print the both average prices and then write a conclusion about
#
# Hint: Create a new column called `pps` (price per square) and then analyse the values

# %%
valdemorillo_data = ds.loc[ds['level5'] == "Valdemorillo", ['price', 'surface']]
galapagar_data = ds.loc[ds['level5'] == "Galapagar", ['price', 'surface']]

valdemorillo_data['pps'] = valdemorillo_data['price'] / valdemorillo_data['surface']
galapagar_data['pps'] = galapagar_data['price'] / galapagar_data['surface']

average_valdemorillo_pps = valdemorillo_data['pps'].mean()
average_galapagar_pps = galapagar_data['pps'].mean()

print("Average price per square meter in Valdemorillo:", average_valdemorillo_pps)
print("Average price per square meter in Galapagar:", average_galapagar_pps)

if average_valdemorillo_pps == average_galapagar_pps:
    print("The average price per square meter in Valdemorillo and Galapagar is the same.")
else:
    print("The average price per square meter in Valdemorillo and Galapagar is different.")
# Out:
# Average price per square meter in Valdemorillo: 1317.9502109024986
# Average price per square meter in Galapagar: 1606.3240303094024
# The average price per square meter in Valdemorillo and Galapagar is different.

# %% [markdown]
# #### Exercise 11. Analyse the relation between the surface and the price of the houses (★★☆)
#
# Hint: You can make a `scatter plot` and then write a conclusion about it

# %%
import matplotlib.pyplot as plt

valdemorillo_data = ds[ds['level5'] == "Valdemorillo"]
galapagar_data = ds[ds['level5'] == "Galapagar"]

valdemorillo_square_meters = valdemorillo_data['surface']
valdemorillo_price = valdemorillo_data['price']

galapagar_square_meters = galapagar_data['surface']
galapagar_price = galapagar_data['price']

plt.figure(figsize=(20, 5))

plt.subplot(1, 2, 1)
plt.scatter(valdemorillo_square_meters, valdemorillo_price, alpha=0.5)
plt.title("Valdemorillo: Price vs. Surface")
plt.xlabel("Surface")
plt.ylabel("Price")
plt.grid(True, linestyle='--', alpha=0.7)

plt.subplot(1, 2, 1)
plt.scatter(galapagar_square_meters, galapagar_price, alpha=0.5)
plt.title("Galapagar: Price vs. Surface")
plt.xlabel("Surface")
plt.ylabel("Price")
plt.grid(True, linestyle='--', alpha=0.7)

plt.tight_layout()
plt.show()

# %% [markdown]
# In Valdemorillos (blue) , there is a less of increase in price as surface increases. In Galapagar (orange), not taking into account the clear outlier, you can see that surface seems to have as clear as an effect on price. Price seems to rise expotentially as surface increases only slightly.

# %% [markdown]
# #### Exercise 12. How many real estate agencies the dataset contains? (★★☆)
#
# Print the obtained value

# %%
agencies = ds['realEstate_name'].nunique()

print("Number of real estate agencies in the dataset:", agencies)
# Out:
# Number of real estate agencies in the dataset: 1821

# %% [markdown]
# #### Exercise 13. Which is the population (level5 column) that contains the most houses? (★★☆)
#
# Print both the population and the number of houses

# %%
import pandas as pd



most_houses_population = ds['level5'].value_counts().idxmax()
num_houses_in_population = ds['level5'].value_counts().max()

print("Population with the most houses:", most_houses_population)
print("Number of houses in that population:", num_houses_in_population)
# Out:
# Population with the most houses:  Madrid Capital
# Number of houses in that population: 6643

# %% [markdown]
# #### Exercise 14. Now let's work with the "south belt" of madrid. Make a subset of the original DataFrame that contains the following populations (level5 column): "Fuenlabrada","Leganés","Getafe","Alcorcón" (★★☆)
#
# Hint: Filter the original DataFrame using the column `level5` and the function `isin`

# %%
south_belt_populations = ["Fuenlabrada", "Leganés", "Getafe", "Alcorcón"]

south_belt_subset = ds[ds['level5'].isin(south_belt_populations)]

print(south_belt_subset.head())
# Out:
#      Unnamed: 0  id_realEstates  isNew                    realEstate_name  \
# 1             2       153867863  False  tecnocasa fuenlabrada ferrocarril
# 3             4       152776331  False  tecnocasa fuenlabrada ferrocarril
# 85           86       153152077  False            sinergical inmobiliaria
# 94           95       153995577  False                    viviendas365com
# 109         110       153586414  False    area uno asesores inmobiliarios
#
#      phone_realEstate                                       url_inmueble  \
# 1         916358736.0  https://www.fotocasa.es/es/comprar/vivienda/ma...
# 3         916358736.0  https://www.fotocasa.es/es/comprar/vivienda/ma...
# 85                NaN  https://www.fotocasa.es/es/comprar/vivienda/le...
# 94        911226014.0  https://www.fotocasa.es/es/comprar/vivienda/le...
# 109       912664081.0  https://www.fotocasa.es/es/comprar/vivienda/ma...
#
#      rooms  bathrooms  surface   price  ... level4Id level5Id level6Id  \
# ...

# %% [markdown]
# #### Exercise 15. Make a bar plot of the median of the prices and explain what you observe (you must use the subset obtained in the question 14) (★★★)
#
# Print the bar of the median of the prices and write in the Markdown cell a brief analysis about the plot

# %%
import matplotlib.pyplot as plt

# Calculate the median prices for each population in the subset
median_prices = south_belt_subset.groupby('level5')['price'].median().sort_values()

# Create a bar plot
plt.figure(figsize=(10, 6))
median_prices.plot(kind='bar', color='blue')
plt.title("Median Prices in the South Belt of Madrid")
plt.xlabel("Population")
plt.ylabel("Median Price")
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %% [markdown]
# Looking at the bar graph, you can make the conclusion that Fuenlabrada, Leganes and Alcorcon have similiar median prices. Getafe on the other hand has a significantly higher median price. Why might this be? Getafe although is close to the other populations, it might be a more affluent population. Also, there could be less data on Getafe than the other populations, thus skewing the median result. Outliers might also be taking an effect on the result.

# %% [markdown]
# #### Exercise 16. Calculate the sample mean and variance of the variables: price, rooms, surface area and bathrooms (you must use the subset obtained in the question 14) (★★★)
#
# Print both values for each variable

# %%
import pandas as pd


south_belt_populations = ["Fuenlabrada", "Leganés", "Getafe", "Alcorcón"]

south_belt_subset = ds[ds['level5'].isin(south_belt_populations)]

mean_price = south_belt_subset['price'].mean()
variance_price = south_belt_subset['price'].var()

mean_rooms = south_belt_subset['rooms'].mean()
variance_rooms = south_belt_subset['rooms'].var()

mean_surface_area = south_belt_subset['surface'].mean()
variance_surface_area = south_belt_subset['surface'].var()

mean_bathrooms = south_belt_subset['bathrooms'].mean()
variance_bathrooms = south_belt_subset['bathrooms'].var()

print("Sample Mean and Variance for Price:")
print("Mean Price:", mean_price)
print("Variance Price:", variance_price)

print("\nSample Mean and Variance for Rooms:")
print("Mean Rooms:", mean_rooms)
print("Variance Rooms:", variance_rooms)

print("\nSample Mean and Variance for Surface Area:")
print("Mean Surface Area:", mean_surface_area)
print("Variance Surface Area:", variance_surface_area)

print("\nSample Mean and Variance for Bathrooms:")
print("Mean Bathrooms:", mean_bathrooms)
print("Variance Bathrooms:", variance_bathrooms)
# Out:
# Sample Mean and Variance for Price:
# Mean Price: 223094.48070562293
# Variance Price: 14921367508.04902
#
# Sample Mean and Variance for Rooms:
# Mean Rooms: 3.0177383592017737
# Variance Rooms: 0.7188858892927542
#
# Sample Mean and Variance for Surface Area:
# Mean Surface Area: 111.75222363405337
# Variance Surface Area: 4263.051760316337
#
# Sample Mean and Variance for Bathrooms:
# Mean Bathrooms: 1.633221850613155
# Variance Bathrooms: 0.5717968625577321

# %% [markdown]
# #### Exercise 17. What is the most expensive house of each population? You must use the subset obtained in the question 14 (★★☆)
#
# Print both the address and the price of the selected house of each population. You can print a DataFrame or a single line for each population

# %%
most_expensive_houses = south_belt_subset.groupby('level5').apply(lambda x: x.loc[x['price'].idxmax()])


for _, row in most_expensive_houses.iterrows():
    print(f"Population: {row['level5']} USD")
    print(f"Address: {row['address']} USD")
    print(f"Price: {row['price']} USD")
    print()
# Out:
# Population: Alcorcón USD
# Address: Alcorcón USD
# Price: 950000 USD
#
# Population: Fuenlabrada USD
# Address: Calle de Paulo Freire, 5, Fuenlabrada USD
# Price: 490000 USD
#
# Population: Getafe USD
# Address: Getafe USD
# Price: 1050000 USD
#
# Population: Leganés USD
# Address: Avenida Reina Sofía, Leganés USD
# Price: 650000 USD

# %% [markdown]
# #### Exercise 18. Normalize the variable of prices for each population and plot the 4 histograms in the same plot (you must use the subset obtained in the question 14) (★★★)
#
# For the normalization method you can use the one you consider to, there is not a single correct answer to this question. Print the plot and write in the Markdown cell a brief analysis about the plot
#
# Hint: You can help yourself reviewing the multihist demo of Matplotlib

# %%
import matplotlib.pyplot as plt
import numpy as np

fig, ax = plt.subplots(figsize=(10, 6))

populations = ["Fuenlabrada", "Leganés", "Getafe", "Alcorcón"]

normalized_prices = []

for population in populations:
    population_data = south_belt_subset[south_belt_subset['level5'] == population]
    prices = population_data['price']
    
    min_price, max_price = prices.min(), prices.max()
    normalized_price = (prices - min_price) / (max_price - min_price)
    
    normalized_prices.append(normalized_price)

plt.hist(
    normalized_prices,
    bins=20,
    alpha=0.7,
    label=populations
)

plt.title("Normalized Prices Histogram for Different Populations")
plt.xlabel("Normalized Price")
plt.ylabel("Frequency")
plt.legend(title="Population")

plt.show()

# %% [markdown]
# All of the populations are right-skewed except for Getafe which seems to have a multi-modal distribution. There is a trend of more properties in the 100k-200k USD range in all the populations. However, Getafe seems to heve an excess of properties in the 300k-400k USD range that are not as prevalent in the other populations.

# %% [markdown]
# #### Exercise 19. What can you say about the price per square meter (price/m2) between the towns of "Getafe" and "Alcorcón"? You must use the subset obtained in the question 14 (★★☆)
#
# Hint: Create a new column called `pps` (price per square) and then analyse the values

# %%
south_belt_subset['pps'] = south_belt_subset['price'] / south_belt_subset['surface']

getafe_data = south_belt_subset.loc[south_belt_subset['level5'] == 'Getafe'].copy()
alcorcon_data = south_belt_subset.loc[south_belt_subset['level5'] == 'Alcorcón'].copy()



mean_pps_getafe = getafe_data['pps'].mean()
mean_pps_alcorcon = alcorcon_data['pps'].mean()


print("Mean Price per Square Meter in Getafe:", mean_pps_getafe)
print("Mean Price per Square Meter in Alcorcón:", mean_pps_alcorcon)
# Out:
# Mean Price per Square Meter in Getafe: 2066.314949251463
# Mean Price per Square Meter in Alcorcón: 2239.302480199618
# /tmp/ipykernel_1077/4154772755.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   south_belt_subset['pps'] = south_belt_subset['price'] / south_belt_subset['surface']

# %% [markdown]
# Persistent copy warning /tmp/ipykernel_698/4093106990.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead.
#
# Have no idea how to remove it. However, i believe it is not affecting my data.

# %% [markdown]
# #### Exercise 20. Make the same plot for 4 different populations (level5 column) and rearrange them on the same graph? You must use the subset obtained in the question 14 (★★☆)
# Hint: make a scatter plot of each population using subplots.

# %%
import matplotlib.pyplot as plt
import pandas as pd

populations = ["Fuenlabrada", "Leganés", "Getafe", "Alcorcón"]

fig, axes = plt.subplots(2, 2, figsize=(12, 8))
axes = axes.flatten()

for i, population in enumerate(populations):
    population_data = south_belt_subset[south_belt_subset['level5'] == population]
    
    axes[i].scatter(population_data['surface'], population_data['price'], label=population, alpha=0.5)
    axes[i].set_title(f"Scatter Plot for {population}")
    axes[i].set_xlabel("Square Meters")
    axes[i].set_ylabel("Price")
    axes[i].legend()

plt.tight_layout()

plt.show()

# %% [markdown]
# #### Exercise 21. Make a plot of the coordinates (latitude and longitude columns) of the south belt of Madrid by color of each population (you must use the subset obtained in the question 14) (★★★★)
#
# Execute the following cell and then start coding in the next one. You must implement a simple code that transform the coordinates columns in a Python dictionary (add more information if needed) and then add it to the map

# %%
from ipyleaflet import Map, basemaps

# Map centred on (60 degrees latitude et -2.2 degrees longitude)
# Latitude, longitude
map = Map(center = (60, -2.2), zoom = 2, min_zoom = 1, max_zoom = 20, 
    basemap=basemaps.Stamen.Terrain)
map
# Out:
# Map(center=[60, -2.2], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', 'zoom_out_t…

# %%
from ipyleaflet import Map, basemaps

# Map centred on (60 degrees latitude et -2.2 degrees longitude)
# Latitude, longitude
map = Map(center = (60, -2.2), zoom = 2, min_zoom = 1, max_zoom = 20, 
    basemap=basemaps.Stamen.Terrain)
map

import pandas as pd

ds = pd.read_csv('../assets/real_estate.csv', sep=';')

south_belt_populations = ["Fuenlabrada", "Leganés", "Getafe", "Alcorcón"]

south_belt_subset = ds[ds['level5'].isin(south_belt_populations)]

population_coordinates = {
    "Fuenlabrada": [],
    "Leganés": [],
    "Getafe": [],
    "Alcorcón": []
}

for index, row in south_belt_subset.iterrows():
    latitude = row['latitude']
    longitude = row['longitude']
    population = row['level5']
    
    population_coordinates[population].append((latitude, longitude))

from ipyleaflet import Map, basemaps, Marker, LayerGroup

m = Map(center=(60, -2.2), zoom=2, min_zoom=1, max_zoom=20, basemap=basemaps.Stamen.Terrain)

population_coordinates = {
    "Fuenlabrada": [(40.294, -3.792), (40.292, -3.790), (40.290, -3.789)],
    "Leganés": [(40.341, -3.761), (40.339, -3.760), (40.336, -3.759)],
    "Getafe": [(40.308, -3.731), (40.306, -3.730), (40.304, -3.729)],
    "Alcorcón": [(40.347, -3.827), (40.345, -3.826), (40.343, -3.825)]
}

markers = []

for population, coordinates in population_coordinates.items():
    for coord in coordinates:
        marker = Marker(location=coord, title=population)
        markers.append(marker)

marker_layer = LayerGroup(layers=markers)

m.add_layer(marker_layer)

m
# Out:
# Map(center=[60, -2.2], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', 'zoom_out_t…

# %% [markdown]
# Not quite the right code I believe. Struggling to figure out how to add all the population markers and change their colors.
